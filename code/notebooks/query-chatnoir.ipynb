# %%
from os import environ

if "CHATNOIR_API_KEY_STAGING" in environ:
    api_key = environ["CHATNOIR_API_KEY_STAGING"]
else:
    api_key = input("ChatNoir API key: ")

# %%
from sys import modules

if "google.colab" in modules:
    # !pip install -q chatnoir-pyterrier python-terrier

# %%
from pyterrier import init, started

if not started():
    init()
# Out:
# PyTerrier 0.9.1 has loaded Terrier 5.7 (built by craigm on 2022-11-10 18:30) and terrier-helper 0.0.7

# %%
from requests import get
from pandas import DataFrame, read_xml
from pathlib import Path


def download_read_topics(url: str, path: Path) -> DataFrame:
    if not path.exists():
        with path.open("wb") as file:
            file.write(get(url).content)
    return read_xml(path).rename(columns={"number": "qid", "title": "query"}).drop(columns=["description", "narrative"])

# %%
topics_task_1 = download_read_topics(
    "https://touche.webis.de/clef23/touche23-data/topics-task1.xml",
    Path("topics_task_1.xml")
)
topics_task_2 = download_read_topics(
    "https://touche.webis.de/clef23/touche23-data/topics-task2.xml",
    Path("topics_task_2.xml")
)

# %%
topics_task_1
# Out:
#     qid                                              query
# 0     1                        Should teachers get tenure?
# 1     2                  Is vaping with e-cigarettes safe?
# 2     3                 Should insider trading be allowed?
# 3     4     Should corporal punishment be used in schools?
# 4     5              Should social security be privatized?
# 5     6                   Is a college education worth it?
# 6     7  Should felons who have completed their sentenc...
# 7     8                          Should abortion be legal?
# 8     9      Should students have to wear school uniforms?
# 9    10      Should any vaccines be required for children?
# 10   11  Should performance-enhancing drugs be accepted...
# 11   12  Should birth control pills be available over t...
# 12   13  Can alternative energy effectively replace fos...
# 13   14         Is sexual orientation determined at birth?
# 14   15  Should animals be used for scientific or comme...
# 15   16  Should prescription drugs be advertised direct...
# 16   17            Should recreational marijuana be legal?
# 17   18                 Should churches remain tax-exempt?
# 18   19                      Should gay marriage be legal?
# 19   20               Is drinking milk healthy for humans?
# 20   21  Is human activity primarily responsible for gl...
# 21   22  Is a two-state solution an acceptable solution...
# 22   23  Should euthanasia or physician-assisted suicid...
# 23   24  Does lowering the federal corporate income tax...
# 24   25                          Should education be free?
# 25   26           Do standardized tests improve education?
# 26   27           Should more gun control laws be enacted?
# 27   28                      Should prostitution be legal?
# 28   29  Should the government allow illegal immigrants...
# 29   30  Should adults have the right to carry a concea...
# 30   31                              Is obesity a disease?
# 31   32  Do electronic voting machines improve the voti...
# 32   33                   Should people become vegetarian?
# 33   34  Are social networking sites good for our society?
# 34   35  Do violent video games contribute to youth vio...
# 35   36                                   Is golf a sport?
# 36   37                      Is cell phone radiation safe?
# 37   38              Should marijuana be a medical option?
# 38   39      Should the federal minimum wage be increased?
# 39   40               Should the death penalty be allowed?
# 40   41  Should student loan debt be easier to discharg...
# 41   42              Should fighting be allowed in hockey?
# 42   43                    Should bottled water be banned?
# 43   44         Should election day be a national holiday?
# 44   45              Should the penny stay in circulation?
# 45   46                 Should net neutrality be restored?
# 46   47                            Is homework beneficial?
# 47   48                  Should the voting age be lowered?
# 48   49       Should body cameras be mandatory for police?
# 49   50      Should everyone get a universal basic income?

# %%
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
import pandas as pd
import string
import stanza

stop_words = set(stopwords.words('english'))

nlp = stanza.Pipeline(lang='en', processors='tokenize,pos,lemma', use_gpu=False)

def lemmatize_sentence(sentence):
    doc = nlp(sentence)
    lemmatized_words = [word.lemma for sent in doc.sentences for word in sent.words]
    lemmatized_sentence = ' '.join(lemmatized_words)
    return lemmatized_sentence

def lemmatize_sentence_remove_punct(sentence):
    doc = nlp(sentence)
    lemmatized_words = [word.lemma for sent in doc.sentences for word in sent.words]
    lemmatized_sentence = ' '.join(lemmatized_words)
    return lemmatized_sentence.replace('?', '')

custom_stopword_list = ['be', 'a', 'the', 'do', 'to', 'at', 'we', 'for', 'or', 'in', 'it']

def remove_custom_stop_words(sentence):
    return ' '.join([word.lower() for word in sentence.split() if word.lower() not in custom_stopword_list])

custom_arg_words = ['pro', 'con', 'benefit', 'because', 'opinion', 'believe', 'think', 'issue', 'justify', 'debate', 'argument', 'evidence', 'fact', 'example', 'reason']

def add_arg_cues(sentence):
    return sentence + ' ' + ' '.join(custom_arg_words)

#topics_task_1['query'] = topics_task_1['query'].apply(lambda x: ' '.join([word.lower() for word in x.split() if word.lower() not in stop_words])\
#                                                  .translate(str.maketrans('', '', string.punctuation)))
#topics_task_1['query'] = topics_task_1['query'].apply(lemmatize_sentence)


topics_task_1['query'] = topics_task_1['query'].apply(lemmatize_sentence_remove_punct)
topics_task_1['query'] = topics_task_1['query'].apply(remove_custom_stop_words)
#topics_task_1['query'] = topics_task_1['query'].apply(add_arg_cues)
# Out:
# 2023-04-27 10:37:22 INFO: Loading these models for language: en (English):
# =======================
# | Processor | Package |
# -----------------------
# | tokenize  | ewt     |
# | pos       | ewt     |
# | lemma     | ewt     |
# =======================
#
# 2023-04-27 10:37:22 INFO: Use device: cpu
# 2023-04-27 10:37:22 INFO: Loading: tokenize
# 2023-04-27 10:37:22 INFO: Loading: pos
# 2023-04-27 10:37:23 INFO: Loading: lemma
# 2023-04-27 10:37:23 INFO: Done loading processors!

# %%
topics_task_1
# Out:
#     qid                                              query
# 0     1  should teacher get tenure pro con benefit beca...
# 1     2  vape with e-cigarette safe pro con benefit bec...
# 2     3  should insider trading allow pro con benefit b...
# 3     4  should corporal punishment use school pro con ...
# 4     5  should social security privatize pro con benef...
# 5     6  college education worth pro con benefit becaus...
# 6     7  should felon who have complete they sentence a...
# 7     8  should abortion legal pro con benefit because ...
# 8     9  should student have wear school uniform pro co...
# 9    10  should any vaccine require child pro con benef...
# 10   11  should performance - enhance drug accept sport...
# 11   12  should birth control pill available over count...
# 12   13  can alternative energy effectively replace fos...
# 13   14  sexual orientation determine birth pro con ben...
# 14   15  should animal use scientific commercial testin...
# 15   16  should prescription drug advertise directly co...
# 16   17  should recreational marijuana legal pro con be...
# 17   18  should church remain tax - exempt pro con bene...
# 18   19  should gay marriage legal pro con benefit beca...
# 19   20  drink milk healthy human pro con benefit becau...
# 20   21  human activity primarily responsible global cl...
# 21   22  two - state solution acceptable solution israe...
# 22   23  should euthanasia physician - assist suicide l...
# 23   24  lower federal corporate income tax rate create...
# 24   25  should education free pro con benefit because ...
# 25   26  standardize test improve education pro con ben...
# 26   27  should more gun control law enact pro con bene...
# 27   28  should prostitution legal pro con benefit beca...
# 28   29  should government allow illegal immigrant beco...
# 29   30  should adult have right carry conceal handgun ...
# 30   31  obesity disease pro con benefit because opinio...
# 31   32  electronic voting machine improve voting proce...
# 32   33  should people become vegetarian pro con benefi...
# 33   34  social networking site good society pro con be...
# 34   35  violent video game contribute youth violence p...
# 35   36  golf sport pro con benefit because opinion bel...
# 36   37  cell phone radiation safe pro con benefit beca...
# 37   38  should marijuana medical option pro con benefi...
# 38   39  should federal minimum wage increase pro con b...
# 39   40  should death penalty allow pro con benefit bec...
# 40   41  should student loan debt easier discharge bank...
# 41   42  should fight allow hockey pro con benefit beca...
# 42   43  should bottle water ban pro con benefit becaus...
# 43   44  should election day national holiday pro con b...
# 44   45  should penny stay circulation pro con benefit ...
# 45   46  should net neutrality restore pro con benefit ...
# 46   47  homework beneficial pro con benefit because op...
# 47   48  should voting age lower pro con benefit becaus...
# 48   49  should body camera mandatory police pro con be...
# 49   50  should everyone get universal basic income pro...

# %%
from chatnoir_pyterrier.retrieve import ChatNoirRetrieve, Feature
from chatnoir_api import Index
from chatnoir_pyterrier import ChatNoirRetrieve

features = Feature.CONTENT_PLAIN | Feature.TITLE_TEXT  # plaintext and title
chatnoir_all = ~ChatNoirRetrieve(api_key, index=Index.ClueWeb22, staging=True, features=features, verbose=True, num_results=10)
chatnoir_all.transform(topics_task_1).to_csv('../../data/chatnoir_10_custom_stopw_lemmas.tsv', sep='\t', index=False)
# Out:
# Searching with ChatNoir:   0%|          | 0/50 [00:00<?, ?query/s]/home/aqvbw/.local/lib/python3.8/site-packages/dataclasses_json/core.py:171: RuntimeWarning: `NoneType` object value of non-optional type content_type detected when decoding ResultResponseStaging.
#   warnings.warn(f"`NoneType` object {warning}.", RuntimeWarning)
# Searching with ChatNoir:   4%|▍         | 2/50 [00:03<01:21,  1.70s/query]/home/aqvbw/.local/lib/python3.8/site-packages/dataclasses_json/core.py:171: RuntimeWarning: `NoneType` object value of non-optional type content_type detected when decoding ResultResponseStaging.
#   warnings.warn(f"`NoneType` object {warning}.", RuntimeWarning)
# Searching with ChatNoir:   6%|▌         | 3/50 [00:06<01:47,  2.29s/query]/home/aqvbw/.local/lib/python3.8/site-packages/dataclasses_json/core.py:171: RuntimeWarning: `NoneType` object value of non-optional type content_type detected when decoding ResultResponseStaging.
#   warnings.warn(f"`NoneType` object {warning}.", RuntimeWarning)
# Searching with ChatNoir:   8%|▊         | 4/50 [00:09<01:52,  2.44s/query]/home/aqvbw/.local/lib/python3.8/site-packages/dataclasses_json/core.py:171: RuntimeWarning: `NoneType` object value of non-optional type content_type detected when decoding ResultResponseStaging.
#   warnings.warn(f"`NoneType` object {warning}.", RuntimeWarning)
# Searching with ChatNoir:  10%|█         | 5/50 [00:12<02:02,  2.73s/query]/home/aqvbw/.local/lib/python3.8/site-packages/dataclasses_json/core.py:171: RuntimeWarning: `NoneType` object value of non-optional type content_type detected when decoding ResultResponseStaging.
#   warnings.warn(f"`NoneType` object {warning}.", RuntimeWarning)
# Searching with ChatNoir:  12%|█▏        | 6/50 [00:14<01:47,  2.44s/query]/home/aqvbw/.local/lib/python3.8/site-packages/dataclasses_json/core.py:171: RuntimeWarning: `NoneType` object value of non-optional type content_type detected when decoding ResultResponseStaging.
#   warnings.warn(f"`NoneType` object {warning}.", RuntimeWarning)
# Searching with ChatNoir:  14%|█▍        | 7/50 [00:18<02:05,  2.91s/query]/home/aqvbw/.local/lib/python3.8/site-packages/dataclasses_json/core.py:171: RuntimeWarning: `NoneType` object value of non-optional type content_type detected when decoding ResultResponseStaging.
#   warnings.warn(f"`NoneType` object {warning}.", RuntimeWarning)
# Searching with ChatNoir:  16%|█▌        | 8/50 [00:21<02:09,  3.08s/query]/home/aqvbw/.local/lib/python3.8/site-packages/dataclasses_json/core.py:171: RuntimeWarning: `NoneType` object value of non-optional type content_type detected when decoding ResultResponseStaging.
#   warnings.warn(f"`NoneType` object {warning}.", RuntimeWarning)
# Searching with ChatNoir:  18%|█▊        | 9/50 [00:23<01:49,  2.66s/query]/home/aqvbw/.local/lib/python3.8/site-packages/dataclasses_json/core.py:171: RuntimeWarning: `NoneType` object value of non-optional type content_type detected when decoding ResultResponseStaging.
#   warnings.warn(f"`NoneType` object {warning}.", RuntimeWarning)
# Searching with ChatNoir:  20%|██        | 10/50 [00:26<01:51,  2.79s/query]/home/aqvbw/.local/lib/python3.8/site-packages/dataclasses_json/core.py:171: RuntimeWarning: `NoneType` object value of non-optional type content_type detected when decoding ResultResponseStaging.
#   warnings.warn(f"`NoneType` object {warning}.", RuntimeWarning)
# Searching with ChatNoir:  22%|██▏       | 11/50 [00:29<01:53,  2.91s/query]/home/aqvbw/.local/lib/python3.8/site-packages/dataclasses_json/core.py:171: RuntimeWarning: `NoneType` object value of non-optional type content_type detected when decoding ResultResponseStaging.
#   warnings.warn(f"`NoneType` object {warning}.", RuntimeWarning)
# Searching with ChatNoir:  24%|██▍       | 12/50 [00:32<01:49,  2.89s/query]/home/aqvbw/.local/lib/python3.8/site-packages/dataclasses_json/core.py:171: RuntimeWarning: `NoneType` object value of non-optional type content_type detected when decoding ResultResponseStaging.
#   warnings.warn(f"`NoneType` object {warning}.", RuntimeWarning)
# Searching with ChatNoir:  26%|██▌       | 13/50 [00:36<02:01,  3.29s/query]/home/aqvbw/.local/lib/python3.8/site-packages/dataclasses_json/core.py:171: RuntimeWarning: `NoneType` object value of non-optional type content_type detected when decoding ResultResponseStaging.
#   warnings.warn(f"`NoneType` object {warning}.", RuntimeWarning)
# Searching with ChatNoir:  28%|██▊       | 14/50 [00:42<02:21,  3.94s/query]/home/aqvbw/.local/lib/python3.8/site-packages/dataclasses_json/core.py:171: RuntimeWarning: `NoneType` object value of non-optional type content_type detected when decoding ResultResponseStaging.
#   warnings.warn(f"`NoneType` object {warning}.", RuntimeWarning)
# Searching with ChatNoir:  30%|███       | 15/50 [00:45<02:10,  3.72s/query]/home/aqvbw/.local/lib/python3.8/site-packages/dataclasses_json/core.py:171: RuntimeWarning: `NoneType` object value of non-optional type content_type detected when decoding ResultResponseStaging.
#   warnings.warn(f"`NoneType` object {warning}.", RuntimeWarning)
# Searching with ChatNoir:  32%|███▏      | 16/50 [00:49<02:12,  3.88s/query]/home/aqvbw/.local/lib/python3.8/site-packages/dataclasses_json/core.py:171: RuntimeWarning: `NoneType` object value of non-optional type content_type detected when decoding ResultResponseStaging.
#   warnings.warn(f"`NoneType` object {warning}.", RuntimeWarning)
# Searching with ChatNoir:  34%|███▍      | 17/50 [00:52<02:00,  3.64s/query]/home/aqvbw/.local/lib/python3.8/site-packages/dataclasses_json/core.py:171: RuntimeWarning: `NoneType` object value of non-optional type content_type detected when decoding ResultResponseStaging.
#   warnings.warn(f"`NoneType` object {warning}.", RuntimeWarning)
# Searching with ChatNoir:  36%|███▌      | 18/50 [00:54<01:40,  3.13s/query]/home/aqvbw/.local/lib/python3.8/site-packages/dataclasses_json/core.py:171: RuntimeWarning: `NoneType` object value of non-optional type content_type detected when decoding ResultResponseStaging.
#   warnings.warn(f"`NoneType` object {warning}.", RuntimeWarning)
# Searching with ChatNoir:  38%|███▊      | 19/50 [00:56<01:25,  2.76s/query]/home/aqvbw/.local/lib/python3.8/site-packages/dataclasses_json/core.py:171: RuntimeWarning: `NoneType` object value of non-optional type content_type detected when decoding ResultResponseStaging.
#   warnings.warn(f"`NoneType` object {warning}.", RuntimeWarning)
# Searching with ChatNoir:  40%|████      | 20/50 [01:03<01:59,  4.00s/query]/home/aqvbw/.local/lib/python3.8/site-packages/dataclasses_json/core.py:171: RuntimeWarning: `NoneType` object value of non-optional type content_type detected when decoding ResultResponseStaging.
#   warnings.warn(f"`NoneType` object {warning}.", RuntimeWarning)
# Searching with ChatNoir:  42%|████▏     | 21/50 [01:05<01:42,  3.53s/query]/home/aqvbw/.local/lib/python3.8/site-packages/dataclasses_json/core.py:171: RuntimeWarning: `NoneType` object value of non-optional type content_type detected when decoding ResultResponseStaging.
#   warnings.warn(f"`NoneType` object {warning}.", RuntimeWarning)
# Searching with ChatNoir:  44%|████▍     | 22/50 [01:08<01:30,  3.24s/query]/home/aqvbw/.local/lib/python3.8/site-packages/dataclasses_json/core.py:171: RuntimeWarning: `NoneType` object value of non-optional type content_type detected when decoding ResultResponseStaging.
#   warnings.warn(f"`NoneType` object {warning}.", RuntimeWarning)
# Searching with ChatNoir:  46%|████▌     | 23/50 [01:12<01:32,  3.41s/query]/home/aqvbw/.local/lib/python3.8/site-packages/dataclasses_json/core.py:171: RuntimeWarning: `NoneType` object value of non-optional type content_type detected when decoding ResultResponseStaging.
#   warnings.warn(f"`NoneType` object {warning}.", RuntimeWarning)
# Searching with ChatNoir:  48%|████▊     | 24/50 [01:14<01:22,  3.15s/query]/home/aqvbw/.local/lib/python3.8/site-packages/dataclasses_json/core.py:171: RuntimeWarning: `NoneType` object value of non-optional type content_type detected when decoding ResultResponseStaging.
#   warnings.warn(f"`NoneType` object {warning}.", RuntimeWarning)
# Searching with ChatNoir:  50%|█████     | 25/50 [01:18<01:20,  3.22s/query]/home/aqvbw/.local/lib/python3.8/site-packages/dataclasses_json/core.py:171: RuntimeWarning: `NoneType` object value of non-optional type content_type detected when decoding ResultResponseStaging.
#   warnings.warn(f"`NoneType` object {warning}.", RuntimeWarning)
# Searching with ChatNoir:  52%|█████▏    | 26/50 [01:21<01:14,  3.12s/query]/home/aqvbw/.local/lib/python3.8/site-packages/dataclasses_json/core.py:171: RuntimeWarning: `NoneType` object value of non-optional type content_type detected when decoding ResultResponseStaging.
#   warnings.warn(f"`NoneType` object {warning}.", RuntimeWarning)
# Searching with ChatNoir:  54%|█████▍    | 27/50 [01:23<01:07,  2.95s/query]/home/aqvbw/.local/lib/python3.8/site-packages/dataclasses_json/core.py:171: RuntimeWarning: `NoneType` object value of non-optional type content_type detected when decoding ResultResponseStaging.
#   warnings.warn(f"`NoneType` object {warning}.", RuntimeWarning)
# Searching with ChatNoir:  56%|█████▌    | 28/50 [01:27<01:13,  3.36s/query]/home/aqvbw/.local/lib/python3.8/site-packages/dataclasses_json/core.py:171: RuntimeWarning: `NoneType` object value of non-optional type content_type detected when decoding ResultResponseStaging.
#   warnings.warn(f"`NoneType` object {warning}.", RuntimeWarning)
# Searching with ChatNoir:  58%|█████▊    | 29/50 [01:29<00:57,  2.74s/query]/home/aqvbw/.local/lib/python3.8/site-packages/dataclasses_json/core.py:171: RuntimeWarning: `NoneType` object value of non-optional type content_type detected when decoding ResultResponseStaging.
#   warnings.warn(f"`NoneType` object {warning}.", RuntimeWarning)
# Searching with ChatNoir:  60%|██████    | 30/50 [01:32<01:00,  3.03s/query]/home/aqvbw/.local/lib/python3.8/site-packages/dataclasses_json/core.py:171: RuntimeWarning: `NoneType` object value of non-optional type content_type detected when decoding ResultResponseStaging.
#   warnings.warn(f"`NoneType` object {warning}.", RuntimeWarning)
# Searching with ChatNoir:  62%|██████▏   | 31/50 [01:37<01:04,  3.41s/query]/home/aqvbw/.local/lib/python3.8/site-packages/dataclasses_json/core.py:171: RuntimeWarning: `NoneType` object value of non-optional type content_type detected when decoding ResultResponseStaging.
#   warnings.warn(f"`NoneType` object {warning}.", RuntimeWarning)
# Searching with ChatNoir:  64%|██████▍   | 32/50 [01:39<00:56,  3.13s/query]/home/aqvbw/.local/lib/python3.8/site-packages/dataclasses_json/core.py:171: RuntimeWarning: `NoneType` object value of non-optional type content_type detected when decoding ResultResponseStaging.
#   warnings.warn(f"`NoneType` object {warning}.", RuntimeWarning)
# Searching with ChatNoir:  66%|██████▌   | 33/50 [01:42<00:51,  3.01s/query]/home/aqvbw/.local/lib/python3.8/site-packages/dataclasses_json/core.py:171: RuntimeWarning: `NoneType` object value of non-optional type content_type detected when decoding ResultResponseStaging.
#   warnings.warn(f"`NoneType` object {warning}.", RuntimeWarning)
# Searching with ChatNoir:  68%|██████▊   | 34/50 [01:44<00:41,  2.60s/query]/home/aqvbw/.local/lib/python3.8/site-packages/dataclasses_json/core.py:171: RuntimeWarning: `NoneType` object value of non-optional type content_type detected when decoding ResultResponseStaging.
#   warnings.warn(f"`NoneType` object {warning}.", RuntimeWarning)
# Searching with ChatNoir:  70%|███████   | 35/50 [01:47<00:43,  2.89s/query]/home/aqvbw/.local/lib/python3.8/site-packages/dataclasses_json/core.py:171: RuntimeWarning: `NoneType` object value of non-optional type content_type detected when decoding ResultResponseStaging.
#   warnings.warn(f"`NoneType` object {warning}.", RuntimeWarning)
# Searching with ChatNoir:  72%|███████▏  | 36/50 [01:50<00:40,  2.89s/query]/home/aqvbw/.local/lib/python3.8/site-packages/dataclasses_json/core.py:171: RuntimeWarning: `NoneType` object value of non-optional type content_type detected when decoding ResultResponseStaging.
#   warnings.warn(f"`NoneType` object {warning}.", RuntimeWarning)
# Searching with ChatNoir:  74%|███████▍  | 37/50 [01:53<00:37,  2.85s/query]/home/aqvbw/.local/lib/python3.8/site-packages/dataclasses_json/core.py:171: RuntimeWarning: `NoneType` object value of non-optional type content_type detected when decoding ResultResponseStaging.
#   warnings.warn(f"`NoneType` object {warning}.", RuntimeWarning)
# Searching with ChatNoir:  76%|███████▌  | 38/50 [01:55<00:31,  2.60s/query]/home/aqvbw/.local/lib/python3.8/site-packages/dataclasses_json/core.py:171: RuntimeWarning: `NoneType` object value of non-optional type content_type detected when decoding ResultResponseStaging.
#   warnings.warn(f"`NoneType` object {warning}.", RuntimeWarning)
# Searching with ChatNoir:  78%|███████▊  | 39/50 [01:57<00:28,  2.57s/query]/home/aqvbw/.local/lib/python3.8/site-packages/dataclasses_json/core.py:171: RuntimeWarning: `NoneType` object value of non-optional type content_type detected when decoding ResultResponseStaging.
#   warnings.warn(f"`NoneType` object {warning}.", RuntimeWarning)
# Searching with ChatNoir:  80%|████████  | 40/50 [02:00<00:25,  2.53s/query]/home/aqvbw/.local/lib/python3.8/site-packages/dataclasses_json/core.py:171: RuntimeWarning: `NoneType` object value of non-optional type content_type detected when decoding ResultResponseStaging.
#   warnings.warn(f"`NoneType` object {warning}.", RuntimeWarning)
# Searching with ChatNoir:  82%|████████▏ | 41/50 [02:03<00:25,  2.79s/query]/home/aqvbw/.local/lib/python3.8/site-packages/dataclasses_json/core.py:171: RuntimeWarning: `NoneType` object value of non-optional type content_type detected when decoding ResultResponseStaging.
#   warnings.warn(f"`NoneType` object {warning}.", RuntimeWarning)
# Searching with ChatNoir:  84%|████████▍ | 42/50 [02:06<00:21,  2.69s/query]/home/aqvbw/.local/lib/python3.8/site-packages/dataclasses_json/core.py:171: RuntimeWarning: `NoneType` object value of non-optional type content_type detected when decoding ResultResponseStaging.
#   warnings.warn(f"`NoneType` object {warning}.", RuntimeWarning)
# Searching with ChatNoir:  86%|████████▌ | 43/50 [02:08<00:17,  2.50s/query]/home/aqvbw/.local/lib/python3.8/site-packages/dataclasses_json/core.py:171: RuntimeWarning: `NoneType` object value of non-optional type content_type detected when decoding ResultResponseStaging.
#   warnings.warn(f"`NoneType` object {warning}.", RuntimeWarning)
# Searching with ChatNoir:  88%|████████▊ | 44/50 [02:09<00:13,  2.22s/query]/home/aqvbw/.local/lib/python3.8/site-packages/dataclasses_json/core.py:171: RuntimeWarning: `NoneType` object value of non-optional type content_type detected when decoding ResultResponseStaging.
#   warnings.warn(f"`NoneType` object {warning}.", RuntimeWarning)
# Searching with ChatNoir:  90%|█████████ | 45/50 [02:12<00:11,  2.37s/query]/home/aqvbw/.local/lib/python3.8/site-packages/dataclasses_json/core.py:171: RuntimeWarning: `NoneType` object value of non-optional type content_type detected when decoding ResultResponseStaging.
#   warnings.warn(f"`NoneType` object {warning}.", RuntimeWarning)
# Searching with ChatNoir:  92%|█████████▏| 46/50 [02:14<00:09,  2.36s/query]/home/aqvbw/.local/lib/python3.8/site-packages/dataclasses_json/core.py:171: RuntimeWarning: `NoneType` object value of non-optional type content_type detected when decoding ResultResponseStaging.
#   warnings.warn(f"`NoneType` object {warning}.", RuntimeWarning)
# Searching with ChatNoir:  94%|█████████▍| 47/50 [02:16<00:06,  2.12s/query]/home/aqvbw/.local/lib/python3.8/site-packages/dataclasses_json/core.py:171: RuntimeWarning: `NoneType` object value of non-optional type content_type detected when decoding ResultResponseStaging.
#   warnings.warn(f"`NoneType` object {warning}.", RuntimeWarning)
# Searching with ChatNoir:  96%|█████████▌| 48/50 [02:17<00:03,  1.95s/query]/home/aqvbw/.local/lib/python3.8/site-packages/dataclasses_json/core.py:171: RuntimeWarning: `NoneType` object value of non-optional type content_type detected when decoding ResultResponseStaging.
#   warnings.warn(f"`NoneType` object {warning}.", RuntimeWarning)
# Searching with ChatNoir:  98%|█████████▊| 49/50 [02:19<00:01,  1.97s/query]/home/aqvbw/.local/lib/python3.8/site-packages/dataclasses_json/core.py:171: RuntimeWarning: `NoneType` object value of non-optional type content_type detected when decoding ResultResponseStaging.
#   warnings.warn(f"`NoneType` object {warning}.", RuntimeWarning)
# Searching with ChatNoir: 100%|██████████| 50/50 [02:22<00:00,  2.03s/query]/home/aqvbw/.local/lib/python3.8/site-packages/dataclasses_json/core.py:171: RuntimeWarning: `NoneType` object value of non-optional type content_type detected when decoding ResultResponseStaging.
#   warnings.warn(f"`NoneType` object {warning}.", RuntimeWarning)
# Searching with ChatNoir: 100%|██████████| 50/50 [02:24<00:00,  2.89s/query]
#     qid                                              query  \
# 0     1                        Should teachers get tenure?
# 1     2                  Is vaping with e-cigarettes safe?
# 2     3                 Should insider trading be allowed?
# 3     4     Should corporal punishment be used in schools?
# 4     5              Should social security be privatized?
# 5     6                   Is a college education worth it?
# 6     7  Should felons who have completed their sentenc...
# 7     8                          Should abortion be legal?
# 8     9      Should students have to wear school uniforms?
# 9    10      Should any vaccines be required for children?
# 10   11  Should performance-enhancing drugs be accepted...
# 11   12  Should birth control pills be available over t...
# 12   13  Can alternative energy effectively replace fos...
# 13   14         Is sexual orientation determined at birth?
# 14   15  Should animals be used for scientific or comme...
# 15   16  Should prescription drugs be advertised direct...
# 16   17            Should recreational marijuana be legal?
# 17   18                 Should churches remain tax-exempt?
# 18   19                      Should gay marriage be legal?
# 19   20               Is drinking milk healthy for humans?
# 20   21  Is human activity primarily responsible for gl...
# 21   22  Is a two-state solution an acceptable solution...
# 22   23  Should euthanasia or physician-assisted suicid...
# 23   24  Does lowering the federal corporate income tax...
# 24   25                          Should education be free?
# 25   26           Do standardized tests improve education?
# 26   27           Should more gun control laws be enacted?
# 27   28                      Should prostitution be legal?
# 28   29  Should the government allow illegal immigrants...
# 29   30  Should adults have the right to carry a concea...
# 30   31                              Is obesity a disease?
# 31   32  Do electronic voting machines improve the voti...
# 32   33                   Should people become vegetarian?
# 33   34  Are social networking sites good for our society?
# 34   35  Do violent video games contribute to youth vio...
# 35   36                                   Is golf a sport?
# 36   37                      Is cell phone radiation safe?
# 37   38              Should marijuana be a medical option?
# 38   39      Should the federal minimum wage be increased?
# 39   40               Should the death penalty be allowed?
# 40   41  Should student loan debt be easier to discharg...
# 41   42              Should fighting be allowed in hockey?
# 42   43                    Should bottled water be banned?
# 43   44         Should election day be a national holiday?
# 16  Last updated on: 11/13/2018 | Author: ProCon.o...     0
# 17  Last updated on: 8/8/2019 | Author: ProCon.org...     0
# 18  Argumentative Essay : Should Gay Marriage Be L...     0
# 19  Last updated on: 1/31/2020 | Author: ProCon.or...     0
# 20  Is Human Activity Primarily Responsible for Gl...     0
# 21  Last updated on: 2/11/2020 | Author: ProCon.or...     0
# 22  Last updated on: 7/26/2019 | Author: ProCon.or...     0
# 23  Adobe Stock\nAugust 14, 2018\n\nThe Benefits o...     0
# 24  Should All Education be Free Free Essay Exampl...     0
# 25  Do Standardized Tests Improve Education? - The...     0
# 26  Last updated on: 8/1/2017 | Author: ProCon.org...     0
# 27  Last updated on: 11/13/2018 | Author: ProCon.o...     0
# 28  Should Illegal Immigrants Become Citizens Essa...     0
# 29  Concealed Handgun Carry Test Questions! - ProP...     0
# 30  Is obesity a disease?\n\nIs obesity a disease?...     0
# 31  Evm electronic voting machine\nSuccessfully re...     0
# 32  Debate Topic: Should People Become Vegetarian ...     0
# 33  Are Social Networking Sites Good for Our Socie...     0
# 34  Do Violent Video Games Contribute to Youth Vio...     0
# 35  Is golf a sport? | Debate.org\n  • Golf is a s...     0
# 36  Last updated on: 11/9/2018 | Author: ProCon.or...     0
# 37  Last updated on: 1/15/2019 | Author: ProCon.or...     0
# 38  Should the Federal Minimum Wage Be Increased?\...     0
# 39  Should the death penalty be allowed? | Debate....     0
# 40  How to Discharge Student Loans in Bankruptcy -...     0
# 41  Should fighting be allowed in hockey?\n\nIn+an...     0
# 42  Should Bottled Water Be Banned? - 1537 Words |...     0
# 43  Should election day be a national holiday?\n\n...     0
# 44  Should the Penny Stay in Circulation? – Top 3 ...     0
# 45  Net neutrality may be restored under Biden FCC...     0
# 46  Forget about deadlines, with top 2% experts ac...     0
# 47  Should the voting age be lowered to 16?\n\n·Se...     0
# 48  Police Should Wear Body Cameras Essay | ipl.or...     0
# 49  What Is Universal Basic Income, and Should Eve...     0

# %%
#df_chat = pd.read_csv("../../data/chatnoir_50_custom_stopw_lemmas_argterms.tsv", sep='\t')

# %%
#df_chat.head()
# Out:
#    qid                                              query  \
# 0    1  should teacher get tenure pro con benefit beca...
# 1    2  vape with e-cigarette safe pro con benefit bec...
# 2    3  should insider trading allow pro con benefit b...
# 3    4  should corporal punishment use school pro con ...
# 4    5  should social security privatize pro con benef...
#
#                        docno       score  \
# 0  clueweb22-en0018-92-13182  1324.46740
# 1  clueweb22-en0026-12-06583  1443.13300
# 2  clueweb22-en0027-68-01600  1396.56930
# 3  clueweb22-en0037-17-09544  1926.31150
# 4  clueweb22-en0038-21-01810  1007.98505
#
#                                           title_text  \
# 0                [Pros & Cons] | White Coat Investor
# 1  Federal Register :: Treatment of E-Cigarettes ...
# 2      The Pros And Cons Of Bethesda's Creation Club
# 3  The History of Corporal Punishment - The Art a...
# 4  Why do some people think climate change is a h...
#
#                                           html_plain  rank
# 0  This post was originally just a collection of ...     0
# 1  Federal Register :: Treatment of E-Cigarettes ...     0
# 2  The Pros And Cons Of Bethesda's Creation Club\...     0
# 3  The History of Corporal Punishment - The Art a...     0
# 4  Why do some people think climate change is a h...     0
